# %% [markdown]
# # Libros de pruebas
# Este libro contiene las pruebas para poder usar de manera correcta traffic y poder configurarlo acorde a lo necesario para el TFG

# %%
import traffic
print("Funciona la librería")
# Out:
# Funciona la librería

# %%
from traffic.data import opensky

# %%
print("Esta es la ubicación del archivo de configuración: \n")
traffic.config_file
# Out:
# Esta es la ubicación del archivo de configuración
# PosixPath('/Users/jaimebowen/Library/Application Support/traffic/traffic.conf')

# %% [markdown]
# ## Este comando da el lugar donde se encuentra posicionada la carpeta

# %%
flight = opensky.history(
    "2017-02-05",
    # stop is implicit, i.e. stop="2017-02-06"
    callsign="EZY158T",
    return_flight=True
)
print("Funcionan los widgets y las credenciales son correctas")
# Out:
# ...
# Funcionan los widgets y las credenciales son correctas

# %% [markdown]
# ## La siguiente celda comprobará si los archivos nm de EURCONTROL funcionan

# %%
from traffic.data import nm_airspaces
nm_airspaces['LECMBLU']
# Out:
# Airspace LECMBLU [None] (ES)

# %% [markdown]
# En caso de que haya funcionado, se debería ver la forma del sector y los FL en los que se encuentra

# %%
import matplotlib.pyplot as plt
from traffic.drawing import EuroPP, countries

with plt.style.context('traffic'):
    fig = plt.figure()
    ax = plt.axes(projection=EuroPP())

    ax.add_feature(countries())
    ax.gridlines()
    ax.set_extent((-10, 15, 35, 55))

    nm_airspaces['LECMBLU'].plot(ax, lw=2, alpha=.5)

# %% [markdown]
# Su representación sobre España

# %%
print("Si se ha ejectuado hasta aquí, se ha configurado todo a la perfección")
# Out:
# Si se ha ejectuado hasta aquí, se ha configurado todo a la perfección
